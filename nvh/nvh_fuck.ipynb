# %%
# %pip install torch
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
# ...

# %%
# https://www.youtube.com/watch?v=IZtv9s_Wx9I DCGAN
import torch
import torch.nn as nn

class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self)
