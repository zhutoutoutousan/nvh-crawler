# %%
# Generate five random sinuosoidal data, with noise, add them together and fit them with a sinuosoidal function
# using the VSDFT method. The data is generated with the function generate_data() and the fitting is done with
# the function fit_data(). The function plot_data() plots the data and the fitting. The function plot_error()
# plots the error of the fitting. The function plot_error() plots the error of the fitting. The function
# plot_error() plots the error of the fitting. The function plot_error() plots the error of the fitting.

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.optimize import Bounds
from scipy.optimize import LinearConstraint
from scipy.optimize import NonlinearConstraint
from scipy.optimize import BFGS
from scipy.optimize import SR1
from scipy.optimize import LbfgsInvHessProduct
from scipy.optimize import OptimizeResult
from scipy.optimize import OptimizeWarning
from scipy.optimize import approx_fprime
from scipy.optimize import check_grad

# Generate data
def generate_data():
    # Generate data
    x = np.linspace(0, 10, 5000)
    y = np.zeros(len(x))
    
    # f(t) variable, used to generate the data, the frequency of the sinuosoidal function rise up with t on the maximum value of 242
    t = 0

    # noise1
    singal1 = np.zeros(len(x))
    for i in range(0, 242):
        t = t + 1
        ft_singal1 = 2 * np.pi * t
        singal1[i] = np.sin(ft_singal1 * x[i])



    noise1 = np.random.normal(0, 0.1, len(x))

    y = signal1 + signal2 + signal3 + noise1

    return x, y

def plot_data(x, y):
    plt.plot(x, y, 'o', label='data')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.show()

x,y = generate_data()

plot_data(x, y)
